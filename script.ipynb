-- %% [markdown]
-- # [dbo].[INMAST]

-- %%
USE [Apollo_Staging]
GO

-- %%
/****** Object:  Table [dbo].[INMAST]    Script Date: 1/19/2022 3:44:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[INMAST](
	[Itemkey] [nvarchar](50) NULL,
	[Desc1] [text] NULL,
	[Desc2] [text] NULL,
	[Reserved1] [text] NULL,
	[PurchconvFctr] [text] NULL,
	[PurchToStkCnvFctr] [text] NULL,
	[SaleToStkCnvFctr] [text] NULL,
	[UseGenCnvFctr] [text] NULL,
	[Weight] [text] NULL,
	[Physcyclecnt] [text] NULL,
	[Seriallotflg] [text] NULL,
	[NumberMask] [text] NULL,
	[DefltSize] [text] NULL,
	[DaysToExpire] [text] NULL,
	[Itemtyp] [nvarchar](50) NULL,
	[ItemSubtyp] [text] NULL,
	[Itemcostmthd] [text] NULL,
	[Oversoldcostmthd] [text] NULL,
	[PriceGrp] [text] NULL,
	[Abckey] [text] NULL,
	[Manufacturer] [text] NULL,
	[Altitemkey] [text] NULL,
	[Prodkey] [text] NULL,
	[Commodkey] [text] NULL,
	[Eccncode] [text] NULL,
	[Itemlength] [text] NULL,
	[Itemwidth] [text] NULL,
	[Itemheight] [text] NULL,
	[Inctrlcode] [text] NULL,
	[Plannercode] [text] NULL,
	[Spare1] [text] NULL,
	[Orderpolicycode] [text] NULL,
	[Orderpoint] [text] NULL,
	[Mrptrigger] [text] NULL,
	[Minorderqty] [text] NULL,
	[Maxorderqty] [text] NULL,
	[Rndfctr] [text] NULL,
	[Safetystockcode] [text] NULL,
	[Safetystockqty] [text] NULL,
	[Stockuomcode] [text] NULL,
	[Purchaseuomcode] [text] NULL,
	[Salesuomcode] [text] NULL,
	[Itemlinearuom] [text] NULL,
	[Yieldfctr] [text] NULL,
	[Spare2] [text] NULL,
	[Forecasttmfence] [text] NULL,
	[Planningtmfence] [text] NULL,
	[Pegindicator] [text] NULL,
	[Backflush] [text] NULL,
	[Levelcode] [text] NULL,
	[Leadtime] [text] NULL,
	[OrderMethod] [text] NULL,
	[Reservedmfg] [text] NULL,
	[Recuserid] [text] NULL,
	[Recdate] [text] NULL,
	[Operatcrncyky] [text] NULL,
	[Altstockuom] [text] NULL,
	[NAStubUnPrc] [text] NULL,
	[NAStunUnCst] [text] NULL,
	[Taxrefid] [text] NULL,
	[Spare3] [text] NULL,
	[Insp_YN] [text] NULL,
	[MSDSTemp_Key] [text] NULL,
	[SpecGravity] [text] NULL,
	[Inter_Typ] [text] NULL,
	[MeasuredBy] [text] NULL,
	[LotSizingMthd] [text] NULL,
	[BoilingPoint] [text] NULL,
	[CASnbr] [text] NULL,
	[ChemicalName] [text] NULL,
	[DelayedHealthHazard] [text] NULL,
	[FireHazard] [text] NULL,
	[FlashPoint] [text] NULL,
	[FlashPointMethod] [text] NULL,
	[Gas] [text] NULL,
	[HMISChronic] [text] NULL,
	[HMISFlammability] [text] NULL,
	[HMISHealth] [text] NULL,
	[HMISPersProt] [text] NULL,
	[HMISReactivity] [text] NULL,
	[ImmedHealthHaz] [text] NULL,
	[Liquid] [text] NULL,
	[LowerExplosiveLimit] [text] NULL,
	[MatClassifications] [text] NULL,
	[Mixture] [text] NULL,
	[Pure] [text] NULL,
	[ReactivityHazard] [text] NULL,
	[Solid] [text] NULL,
	[SuddenRlsOfPress] [text] NULL,
	[TradeSecret] [text] NULL,
	[UpperExplosiveLimit] [text] NULL,
	[VPmmHg] [text] NULL,
	[VPTemp] [text] NULL,
	[OtherInfo] [text] NULL,
	[Salsp_Com_Ky] [text] NULL,
	[SalesQC] [text] NULL,
	[MfgQC] [text] NULL,
	[AdditionalComm] [text] NULL,
	[CommEffectDate] [text] NULL,
	[CommExpDate] [text] NULL,
	[PSrLotAutoGen] [text] NULL,
	[PCustomPosition] [text] NULL,
	[POptional] [text] NULL,
	[PCustom] [text] NULL,
	[PDateFormat] [text] NULL,
	[PSeqNo] [text] NULL,
	[MSrLotAutoGen] [text] NULL,
	[MCustomPosition] [text] NULL,
	[MOptional] [text] NULL,
	[MCustom] [text] NULL,
	[MDateFormat] [text] NULL,
	[MSeqNo] [text] NULL,
	[MultipleBinsReq] [text] NULL,
	[LotIssueMethod] [text] NULL,
	[PUseSeqNo] [text] NULL,
	[MUseSeqNo] [text] NULL,
	[DaysToQuarantine] [text] NULL,
	[INCI] [text] NULL,
	[EINICS] [text] NULL,
	[Produomcode] [text] NULL,
	[ShipShLife] [text] NULL,
	[ProdShLife] [text] NULL,
	[FGExpShLife] [text] NULL,
	[UPCCODE] [text] NULL,
	[StrgCndtnKey] [text] NULL,
	[PrintableDesc] [text] NULL,
	[PurShelfLife] [text] NULL,
	[CreateDate] [text] NULL,
	[CreateUserID] [text] NULL,
	[ModifyDate] [text] NULL,
	[ModifyUserID] [text] NULL,
	[AllowSerialization] [text] NULL,
	[AllowPartIssueSerialization] [text] NULL,
	[Purchasable] [text] NULL,
	[Saleable] [text] NULL,
	[DefaultContainerQty] [text] NULL,
	[PurQCType] [text] NULL,
	[SpecificationTemplate] [text] NULL,
	[NFPA1] [text] NULL,
	[NFPA2] [text] NULL,
	[NFPA3] [text] NULL,
	[NFPA4] [text] NULL,
	[DfltCntBOM] [text] NULL,
	[AllowPalletization] [text] NULL,
	[User1] [text] NULL,
	[User2] [text] NULL,
	[User3] [text] NULL,
	[User4] [text] NULL,
	[User5] [text] NULL,
	[User6] [text] NULL,
	[User7] [text] NULL,
	[User8] [text] NULL,
	[User9] [text] NULL,
	[User10] [text] NULL,
	[User11] [text] NULL,
	[User12] [text] NULL,
	[ESG_REASON] [text] NULL,
	[ESG_APPROVER] [text] NULL,
	[CUSTOM1] [text] NULL,
	[CUSTOM2] [text] NULL,
	[CUSTOM3] [text] NULL,
	[CUSTOM4] [text] NULL,
	[CUSTOM5] [text] NULL,
	[CUSTOM6] [text] NULL,
	[CUSTOM7] [text] NULL,
	[CUSTOM8] [text] NULL,
	[CUSTOM9] [text] NULL,
	[CUSTOM10] [text] NULL,
	[ClassificationID] [text] NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO
